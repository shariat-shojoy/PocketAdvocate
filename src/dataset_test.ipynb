# %%
import pandas as pd
df = pd.read_csv('E:\\pocket_advocate\\bd_laws_english.csv')

# %%
df.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0  Unnamed: 0.1 law_descripton  \
# 0             0         0.0           0.0            NaN
# 1             1         1.0           1.0              -
# 2             2         2.0           2.0              -
# 3             3         3.0           3.0              -
# 4             4         4.0           4.0              -
#
#           law_pass_date law_subtitle  \
# 0  11th September, 1836            -
# 1      22nd March, 1850            -
# 2      22nd March, 1850            -
# 3      22nd March, 1850            -
# 4      22nd March, 1850            -
#
#                                    law_title section_chapter_id  \
# 0                    The Districts Act, 1836                  -
# 1  The Public Accountant's Default Act, 1850                  -
# 2  The Public Accountant's Default Act, 1850                  -
# 3  The Public Accountant's Default Act, 1850                  -
# 4  The Public Accountant's Default Act, 1850                  -
#
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0.2    Unnamed: 0  Unnamed: 0.1    section_id        url_id
# count  38552.000000  38552.000000  38552.000000  38552.000000  38552.000000
# mean   19275.500000  19275.500000  19275.500000  26102.040802    671.685023
# std    11129.148126  11129.148126  11129.148126  14788.643077    414.333507
# min        0.000000      0.000000      0.000000      1.000000      1.000000
# 25%     9637.750000   9637.750000   9637.750000  13731.750000    289.000000
# 50%    19275.500000  19275.500000  19275.500000  26320.500000    697.000000
# 75%    28913.250000  28913.250000  28913.250000  40574.250000   1032.000000
# max    38551.000000  38551.000000  38551.000000  50455.000000   1378.000000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 38552 entries, 0 to 38551
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0.2          38552 non-null  int64
#  1   Unnamed: 0            38552 non-null  float64
#  2   Unnamed: 0.1          38552 non-null  float64
#  3   law_descripton        37696 non-null  str
#  4   law_pass_date         38552 non-null  str
#  5   law_subtitle          38552 non-null  str
#  6   law_title             38552 non-null  str
#  7   section_chapter_id    38552 non-null  str
#  8   section_chapter_name  38552 non-null  str
#  9   section_chapter_no    38552 non-null  str
#  10  section_description   38482 non-null  str
#  11  section_id            38552 non-null  float64
#  12  section_name          37968 non-null  str
#  13  url_id                38552 non-null  float64
#  14  vol_ordinance         38007 non-null  str
# ...

# %%
df.shape
# Out:
# (38552, 17)

# %%
df[:100]["law_descripton"].values

# %%
df[:100]["section_description"].values
# Out:
# <StringArray>
# ...

# %%
import pandas as pd
df_for = pd.read_csv('E:\\pocket_advocate\\bdlaws_formatted.csv')

# %%
df_for.head(100)
# Out:
#     Unnamed: 0 law_descripton         law_pass_date  law_subtitle  \
# 0            0            NaN  11th September, 1836           NaN
# 1            1            NaN      22nd March, 1850           NaN
# 2            2            NaN      22nd March, 1850           NaN
# 3            3            NaN      22nd March, 1850           NaN
# 4            4            NaN      22nd March, 1850           NaN
# ..         ...            ...                   ...           ...
# 95          95            NaN     6th October, 1860           NaN
# 96          96            NaN     6th October, 1860           NaN
# 97          97            NaN     6th October, 1860           NaN
# 98          98            NaN     6th October, 1860           NaN
# 99          99            NaN     6th October, 1860           NaN
#
#                                     law_title  section_chapter_id  \
# 0                     The Districts Act, 1836                 NaN
# ...

# %%
df_for.describe()
# Out:
#          Unnamed: 0  law_subtitle  section_chapter_id    section_id  \
# count  38552.000000           0.0        16654.000000  38552.000000
# mean   19275.500000           NaN         1016.629218  26102.040802
# std    11129.148126           NaN          683.185413  14788.643077
# min        0.000000           NaN            2.000000      1.000000
# 25%     9637.750000           NaN          459.000000  13731.750000
# 50%    19275.500000           NaN          898.000000  26320.500000
# 75%    28913.250000           NaN         1714.000000  40574.250000
# max    38551.000000           NaN         2285.000000  50455.000000
#
#              url_id
# count  38552.000000
# mean     671.685023
# std      414.333507
# min        1.000000
# 25%      289.000000
# 50%      697.000000
# 75%     1032.000000
# max     1378.000000

# %%
df_for.shape
# Out:
# (38552, 13)

# %%
df_for.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 38552 entries, 0 to 38551
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            38552 non-null  int64
#  1   law_descripton        31815 non-null  str
#  2   law_pass_date         37790 non-null  str
#  3   law_subtitle          0 non-null      float64
#  4   law_title             38552 non-null  str
#  5   section_chapter_id    16654 non-null  float64
#  6   section_chapter_name  17356 non-null  str
#  7   section_chapter_no    16847 non-null  str
#  8   section_description   38484 non-null  str
#  9   section_id            38552 non-null  int64
#  10  section_name          37055 non-null  str
#  11  url_id                38552 non-null  int64
#  12  vol_ordinance         38552 non-null  str
# dtypes: float64(2), int64(3), str(8)
# memory usage: 3.8 MB
